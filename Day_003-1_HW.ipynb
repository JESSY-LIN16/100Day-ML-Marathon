# %% [markdown]
# ## 練習時間
# 在小量的資料上，我們用眼睛就可以看得出來程式碼是否有跑出我們理想中的結果
#
# 請嘗試想像一個你需要的資料結構 (裡面的值可以是隨機的)，然後用上述的方法把它變成 pandas DataFrame
#
# #### Ex: 想像一個 dataframe 有兩個欄位，一個是國家，一個是人口，求人口數最多的國家
#
# ### Hints: [隨機產生數值](https://blog.csdn.net/christianashannon/article/details/78867204)

# %%
import pandas as pd
import numpy as np

# %%
data = {'國家': ,
        '人口': }
data = pd.DataFrame()

# %%
countryDF = pd.read_csv('data/API_SP.POP.TOTL_DS2_en_csv_v2_10224786.csv')
countryDF.head(5)
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996351.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5643182.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965     ...      \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0     ...
# 1  9166764.0  9345868.0  9533954.0  9731361.0  9938414.0     ...
# 2  5753024.0  5866061.0  5980417.0  6093321.0  6203299.0     ...
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0     ...
# 4    14375.0    15370.0    16412.0    17469.0    18549.0     ...
#
#          2008        2009        2010        2011        2012        2013  \
# ...

# %%
CountryPopulation = pd.DataFrame()
CountryPopulation['Country Name'] = countryDF['Country Name']
CountryPopulation['population'] = countryDF['2017']
# drop world
CountryPopulation = CountryPopulation.drop(257)
CountryPopulation.head(5)
# Out:
#   Country Name  population
# 0        Aruba    105264.0
# 1  Afghanistan  35530081.0
# 2       Angola  29784193.0
# 3      Albania   2873457.0
# 4      Andorra     76965.0

# %%
CountryPopulation.loc[CountryPopulation['population'].idxmax()]
# Out:
# Country Name    IDA & IBRD total
# population            6.3532e+09
# Name: 101, dtype: object
