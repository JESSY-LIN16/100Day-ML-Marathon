# %% [markdown]
# ## HW1. Find a dataset

# %% [markdown]
# ANS:
# ### [Black Friday](https://www.kaggle.com/mehdidag/black-friday)
# ##### The dataset I found is called Black Friday.
# ##### 此資料夾主要紀錄了消費者在黑色星期五的購物資訊。
# 1. 這組資料能夠分析出各年齡層對於哪項類別的產品較有興趣，進而讓產生執行對的行銷方向
# 2. 這組資料由AirBus(空中巴士)的資料科學家上傳
# 3. 資料內主要包含了數值與字串型態，紀錄了購買者的性別、年紀、來自哪個城市、購買的類別與消費金額
# 4. 可以了解各性別與年齡層的購物行為，讓廠商能在購物節開始前備貨

# %% [markdown]
# ## HW2.
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

# %% [markdown]
# ANS:
# 1. 對於車隊而言，車次的安排是非常重要的，時間就是金錢。在相同的車次數下，若能提高載客率、減少空轉率就能提升業績
# 2. 資料來源主要會是來自訂車的紀錄包含APP叫車、Line叫車甚至是電話叫車
# 3. 這些資料須包含叫車的時間、地區、是否為假日、要到的區域
# 4. 透過分析這些資料可以更加了解多數人的叫車習慣，可以更加有方向性的安排車輛到不同的區域做預備，以減少空車的時間

# %% [markdown]
# ## HW3. 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(input, input_hat):
    """
    請完成這個 Function 後往下執行
    """
    return np.sum(np.mean((input - input_hat)**2))

# %%
def mean_absolute_error(input, input_hat):
    return np.sum(np.absolute(input - input_hat))

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 248.761
# The Mean absolute error is 1257.607
